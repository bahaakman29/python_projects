# %%
#hesap sahibinin hesabında 10000 TL para olsun..
#günlük para çekme limiti de 6000 TL olsun..
hesapbakiyesi=10000
günlüklimit=6000

işlem=int(input('''Bankanıza hoşgeldiniz Bahadır Bey
                    Yapmak istediğiniz işlemin numrasını tuşlayınız..
                    1.Para Çekme
                    2.Para Yatırma
                    3.Hesap Bakiyesi Öğrenme
                '''))

if işlem==1 or işlem==2 or işlem==3:
    if işlem==1:
        çekilecektutar=int(input("lütfen çekmek istediğiniz para tutarını giriniz.."))
    
        while çekilecektutar>günlüklimit or çekilecektutar>hesapbakiyesi:
            çekilecektutar=int(input("günlük limiti ve hesap bakiyenizi geçmeyecek bir tutar giriniz lütfen.."))
    
        kalanbakiye=hesapbakiyesi-çekilecektutar
        print("çekilen tutar: {} ve kalan bakiyeniz: {}".format(çekilecektutar,kalanbakiye))

    elif işlem==2:
        yatırılacaktutar=int(input("lütfen yatırmak istediğiniz para tutarını giriniz.."))
        hesapbakiyesi+=yatırılacaktutar
        print("yatırılan tutar: {} ve güncel hesap bakiyeniz: {}".format(yatırılacaktutar,hesapbakiyesi))

    elif işlem==3:
        print("güncel hesap bakiyeniz:{} ".format(hesapbakiyesi)) 

while işlem!=1 or işlem!=2 or işlem!=3:
    işlem=int(input('''Lütfen işlem yapabilmek için 1,2,3 rakamlarından birini tuşlayınız
                       1.Para Çekme
                       2.Para Yatırma
                       3.Hesap Bakiyesi Öğrenme
                         '''))
if işlem==1 or işlem==2 or işlem==3:
    if işlem==1:
        çekilecektutar=int(input("lütfen çekmek istediğiniz para tutarını giriniz.."))
    
        while çekilecektutar>günlüklimit or çekilecektutar>hesapbakiyesi:
            çekilecektutar=int(input("günlük limiti ve hesap bakiyenizi geçmeyecek bir tutar giriniz lütfen.."))
    
        kalanbakiye=hesapbakiyesi-çekilecektutar
        print("çekilen tutar: {} ve kalan bakiyeniz: {}".format(çekilecektutar,kalanbakiye))

    elif işlem==2:
        yatırılacaktutar=int(input("lütfen yatırmak istediğiniz para tutarını giriniz.."))
        hesapbakiyesi+=yatırılacaktutar
        print("yatırılan tutar: {} ve güncel hesap bakiyeniz: {}".format(yatırılacaktutar,hesapbakiyesi))

    elif işlem==3:
        print("güncel hesap bakiyeniz:{} ".format(hesapbakiyesi))
